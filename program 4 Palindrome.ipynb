# %%
test_strng = str(input ('Enter the string to check for palindrome'))
back_strng = reversed (test_strng)
if list(test_strng) == list(back_strng):
  print ('yes, it is a palindrome')

else :
  print ('no, it is not palindrome')
# Out:
# Enter the string to check for palindromecoc
# yes
