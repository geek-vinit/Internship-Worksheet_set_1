# %%
print ('Enter 0 for the side to be calculated')
b = float(input('Enter the base length of right angle traingale in mm'))
v = float(input('Enter the vertical hight of right angle traingle in mm'))
h = float (input('Enter the hypotenus length in mm'))
import math
if b > 0 and v> 0:
  h = math.sqrt(b **2 + v**2)
  print('hypotemuse is',h,'mm')

elif v> 0 and h>0 :
  b = math.sqrt (h **2 - v**2) 
  print ('base is ',b,'mm')

else :
  v = math.sqrt(h**2 - b**2) 
  print ('vertical height is',v,'mm')
# Out:
# Enter 0 for the side to be calculated
